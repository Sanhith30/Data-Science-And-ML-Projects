# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# Out:
# Requirement already satisfied: numpy in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (2.3.2)
# Requirement already satisfied: pandas in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting matplotlib
#   Downloading matplotlib-3.10.5-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.59.1-cp312-cp312-win_amd64.whl.metadata (111 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from matplotlib) (2.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.3.0-cp312-cp312-win_amd64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.5-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.1 MB 1.7 MB/s eta 0:00:05
#    ------ --------------------------------- 1.3/8.1 MB 1.8 MB/s eta 0:00:04
#    ------- -------------------------------- 1.6/8.1 MB 1.6 MB/s eta 0:00:05
#    ------- -------------------------------- 1.6/8.1 MB 1.6 MB/s eta 0:00:05
#    ------- -------------------------------- 1.6/8.1 MB 1.6 MB/s eta 0:00:05
#    --------- ------------------------------ 1.8/8.1 MB 1.2 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.1/8.1 MB 1.2 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.4/8.1 MB 1.2 MB/s eta 0:00:05
#    ------------ --------------------------- 2.6/8.1 MB 1.2 MB/s eta 0:00:05
#    -------------- ------------------------- 2.9/8.1 MB 1.2 MB/s eta 0:00:05
#    ---------------- ----------------------- 3.4/8.1 MB 1.3 MB/s eta 0:00:04
#    ------------------ --------------------- 3.7/8.1 MB 1.3 MB/s eta 0:00:04
#    ------------------- -------------------- 3.9/8.1 MB 1.3 MB/s eta 0:00:04
#    -------------------- ------------------- 4.2/8.1 MB 1.3 MB/s eta 0:00:04
#    --------------------- ------------------ 4.5/8.1 MB 1.3 MB/s eta 0:00:03
#    ------------------------ --------------- 5.0/8.1 MB 1.4 MB/s eta 0:00:03
#    ------------------------- -------------- 5.2/8.1 MB 1.4 MB/s eta 0:00:03
#    --------------------------- ------------ 5.5/8.1 MB 1.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.8/8.1 MB 1.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.0/8.1 MB 1.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.0/8.1 MB 1.3 MB/s eta 0:00:02
#    -------------------------------- ------- 6.6/8.1 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 6.8/8.1 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 1.3 MB/s  0:00:06
# Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.59.1-cp312-cp312-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.3 MB 2.4 MB/s eta 0:00:01
#    ------------- -------------------------- 0.8/2.3 MB 1.3 MB/s eta 0:00:02
#    ------------------ --------------------- 1.0/2.3 MB 1.1 MB/s eta 0:00:02
#    ------------------ --------------------- 1.0/2.3 MB 1.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 1.3/2.3 MB 1.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.3/2.3 MB 1.0 MB/s eta 0:00:01
#    --------------------------- ------------ 1.6/2.3 MB 855.6 kB/s eta 0:00:01
#    --------------------------- ------------ 1.6/2.3 MB 855.6 kB/s eta 0:00:01
#    -------------------------------- ------- 1.8/2.3 MB 818.3 kB/s eta 0:00:01
#    -------------------------------- ------- 1.8/2.3 MB 818.3 kB/s eta 0:00:01
#    -------------------------------- ------- 1.8/2.3 MB 818.3 kB/s eta 0:00:01
#    ------------------------------------- -- 2.1/2.3 MB 752.7 kB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 744.5 kB/s  0:00:02
# Downloading kiwisolver-1.4.9-cp312-cp312-win_amd64.whl (73 kB)
# Downloading pillow-11.3.0-cp312-cp312-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/7.0 MB 1.3 MB/s eta 0:00:06
#    ---- ----------------------------------- 0.8/7.0 MB 1.2 MB/s eta 0:00:05
#    ------- -------------------------------- 1.3/7.0 MB 1.4 MB/s eta 0:00:05
#    ------- -------------------------------- 1.3/7.0 MB 1.4 MB/s eta 0:00:05
#    --------- ------------------------------ 1.6/7.0 MB 1.3 MB/s eta 0:00:05
#    ---------- ----------------------------- 1.8/7.0 MB 1.3 MB/s eta 0:00:05
#    ------------ --------------------------- 2.1/7.0 MB 1.3 MB/s eta 0:00:04
#    ------------- -------------------------- 2.4/7.0 MB 1.3 MB/s eta 0:00:04
#    ---------------- ----------------------- 2.9/7.0 MB 1.4 MB/s eta 0:00:04
#    ------------------- -------------------- 3.4/7.0 MB 1.4 MB/s eta 0:00:03
#    --------------------- ------------------ 3.7/7.0 MB 1.5 MB/s eta 0:00:03
#    ------------------------ --------------- 4.2/7.0 MB 1.5 MB/s eta 0:00:02
#    ------------------------ --------------- 4.2/7.0 MB 1.5 MB/s eta 0:00:02
#    --------------------------- ------------ 4.7/7.0 MB 1.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.0/7.0 MB 1.5 MB/s eta 0:00:02
#    ------------------------------ --------- 5.2/7.0 MB 1.4 MB/s eta 0:00:02
#    ------------------------------- -------- 5.5/7.0 MB 1.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 6.0/7.0 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 6.3/7.0 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 6.3/7.0 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 6.6/7.0 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 1.4 MB/s  0:00:05
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------- ---------------------------- 2/7 [kiwisolver]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------------- 7/7 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.59.1 kiwisolver-1.4.9 matplotlib-3.10.5 pillow-11.3.0 pyparsing-3.2.3
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from seaborn) (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import re
from bs4 import BeautifulSoup

import warnings
warnings.filterwarnings('ignore')

# %%
new_df = pd.read_csv('train.csv')

# %%
new_df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %%
def preprocess(q):
    
    q = str(q).lower().strip()
    
    # Replace certain special characters with their string equivalents
    q = q.replace('%', ' percent')
    q = q.replace('$', ' dollar ')
    q = q.replace('₹', ' rupee ')
    q = q.replace('€', ' euro ')
    q = q.replace('@', ' at ')
    
    # The pattern '[math]' appears around 900 times in the whole dataset.
    q = q.replace('[math]', '')
    
    # Replacing some numbers with string equivalents (not perfect, can be done better to account for more cases)
    q = q.replace(',000,000,000 ', 'b ')
    q = q.replace(',000,000 ', 'm ')
    q = q.replace(',000 ', 'k ')
    q = re.sub(r'([0-9]+)000000000', r'\1b', q)
    q = re.sub(r'([0-9]+)000000', r'\1m', q)
    q = re.sub(r'([0-9]+)000', r'\1k', q)
    
    # Decontracting words
    # https://en.wikipedia.org/wiki/Wikipedia%3aList_of_English_contractions
    # https://stackoverflow.com/a/19794953
    contractions = { 
    "ain't": "am not",
    "aren't": "are not",
    "can't": "can not",
    "can't've": "can not have",
    "'cause": "because",
    "could've": "could have",
    "couldn't": "could not",
    "couldn't've": "could not have",
    "didn't": "did not",
    "doesn't": "does not",
    "don't": "do not",
    "hadn't": "had not",
    "hadn't've": "had not have",
    "hasn't": "has not",
    "haven't": "have not",
    "he'd": "he would",
    "he'd've": "he would have",
    "he'll": "he will",
    "he'll've": "he will have",
    "he's": "he is",
    "how'd": "how did",
    "how'd'y": "how do you",
    "how'll": "how will",
    "how's": "how is",
    "i'd": "i would",
    "i'd've": "i would have",
    "i'll": "i will",
    "i'll've": "i will have",
    "i'm": "i am",
    "i've": "i have",
    "isn't": "is not",
    "it'd": "it would",
    "it'd've": "it would have",
    "it'll": "it will",
    "it'll've": "it will have",
    "it's": "it is",
    "let's": "let us",
    "ma'am": "madam",
    "mayn't": "may not",
    "might've": "might have",
    "mightn't": "might not",
    "mightn't've": "might not have",
    "must've": "must have",
    "mustn't": "must not",
    "mustn't've": "must not have",
    "needn't": "need not",
    "needn't've": "need not have",
    "o'clock": "of the clock",
    "oughtn't": "ought not",
    "oughtn't've": "ought not have",
    "shan't": "shall not",
    "sha'n't": "shall not",
    "shan't've": "shall not have",
    "she'd": "she would",
    "she'd've": "she would have",
    "she'll": "she will",
    "she'll've": "she will have",
    "she's": "she is",
    "should've": "should have",
    "shouldn't": "should not",
    "shouldn't've": "should not have",
    "so've": "so have",
    "so's": "so as",
    "that'd": "that would",
    "that'd've": "that would have",
    "that's": "that is",
    "there'd": "there would",
    "there'd've": "there would have",
    "there's": "there is",
    "they'd": "they would",
    "they'd've": "they would have",
    "they'll": "they will",
    "they'll've": "they will have",
    "they're": "they are",
    "they've": "they have",
    "to've": "to have",
    "wasn't": "was not",
    "we'd": "we would",
    "we'd've": "we would have",
    "we'll": "we will",
    "we'll've": "we will have",
    "we're": "we are",
    "we've": "we have",
    "weren't": "were not",
    "what'll": "what will",
    "what'll've": "what will have",
    "what're": "what are",
    "what's": "what is",
    "what've": "what have",
    "when's": "when is",
    "when've": "when have",
    "where'd": "where did",
    "where's": "where is",
    "where've": "where have",
    "who'll": "who will",
    "who'll've": "who will have",
    "who's": "who is",
    "who've": "who have",
    "why's": "why is",
    "why've": "why have",
    "will've": "will have",
    "won't": "will not",
    "won't've": "will not have",
    "would've": "would have",
    "wouldn't": "would not",
    "wouldn't've": "would not have",
    "y'all": "you all",
    "y'all'd": "you all would",
    "y'all'd've": "you all would have",
    "y'all're": "you all are",
    "y'all've": "you all have",
    "you'd": "you would",
    "you'd've": "you would have",
    "you'll": "you will",
    "you'll've": "you will have",
    "you're": "you are",
    "you've": "you have"
    }

    q_decontracted = []

    for word in q.split():
        if word in contractions:
            word = contractions[word]

        q_decontracted.append(word)

    q = ' '.join(q_decontracted)
    q = q.replace("'ve", " have")
    q = q.replace("n't", " not")
    q = q.replace("'re", " are")
    q = q.replace("'ll", " will")
    
    # Removing HTML tags
    q = BeautifulSoup(q)
    q = q.get_text()
    
    # Remove punctuations
    pattern = re.compile('\W')
    q = re.sub(pattern, ' ', q).strip()

    
    return q

# %%
new_df['question1'] = new_df['question1'].apply(preprocess)
new_df['question2'] = new_df['question2'].apply(preprocess)

# %%
new_df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  what is the step by step guide to invest in sh...
# 1   1     3     4  what is the story of kohinoor  koh i noor  dia...
# 2   2     5     6  how can i increase the speed of my internet co...
# 3   3     7     8  why am i mentally very lonely  how can i solve it
# 4   4     9    10  which one dissolve in water quikly sugar  salt...
#
#                                            question2  is_duplicate
# 0  what is the step by step guide to invest in sh...             0
# 1  what would happen if the indian government sto...             0
# 2  how can internet speed be increased by hacking...             0
# 3  find the remainder when 23  24   math  is divi...             0
# 4             which fish would survive in salt water             0

# %%
new_df['q1_len'] = new_df['question1'].str.len() 
new_df['q2_len'] = new_df['question2'].str.len()

# %%
new_df['q1_num_words'] = new_df['question1'].apply(lambda row: len(row.split(" ")))
new_df['q2_num_words'] = new_df['question2'].apply(lambda row: len(row.split(" ")))
new_df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  what is the step by step guide to invest in sh...
# 1   1     3     4  what is the story of kohinoor  koh i noor  dia...
# 2   2     5     6  how can i increase the speed of my internet co...
# 3   3     7     8  why am i mentally very lonely  how can i solve it
# 4   4     9    10  which one dissolve in water quikly sugar  salt...
#
#                                            question2  is_duplicate  q1_len  \
# 0  what is the step by step guide to invest in sh...             0      65
# 1  what would happen if the indian government sto...             0      50
# 2  how can internet speed be increased by hacking...             0      72
# 3  find the remainder when 23  24   math  is divi...             0      49
# 4             which fish would survive in salt water             0      75
#
#    q2_len  q1_num_words  q2_num_words
# 0      56            14            12
# 1      87            12            17
# 2      58            14            10
# 3      58            12            16
# 4      38            15             7

# %%
def common_words(row):
    w1 = set(map(lambda word: word.lower().strip(), row['question1'].split(" ")))
    w2 = set(map(lambda word: word.lower().strip(), row['question2'].split(" ")))    
    return len(w1 & w2)

# %%
new_df['word_common'] = new_df.apply(common_words, axis=1)
new_df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  what is the step by step guide to invest in sh...
# 1   1     3     4  what is the story of kohinoor  koh i noor  dia...
# 2   2     5     6  how can i increase the speed of my internet co...
# 3   3     7     8  why am i mentally very lonely  how can i solve it
# 4   4     9    10  which one dissolve in water quikly sugar  salt...
#
#                                            question2  is_duplicate  q1_len  \
# 0  what is the step by step guide to invest in sh...             0      65
# 1  what would happen if the indian government sto...             0      50
# 2  how can internet speed be increased by hacking...             0      72
# 3  find the remainder when 23  24   math  is divi...             0      49
# 4             which fish would survive in salt water             0      75
#
#    q2_len  q1_num_words  q2_num_words  word_common
# 0      56            14            12           11
# 1      87            12            17            8
# 2      58            14            10            4
# 3      58            12            16            1
# 4      38            15             7            4

# %%
def total_words(row):
    w1 = set(map(lambda word: word.lower().strip(), row['question1'].split(" ")))
    w2 = set(map(lambda word: word.lower().strip(), row['question2'].split(" ")))    
    return (len(w1) + len(w2))

# %%
new_df['word_total'] = new_df.apply(total_words, axis=1)
new_df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  what is the step by step guide to invest in sh...
# 1   1     3     4  what is the story of kohinoor  koh i noor  dia...
# 2   2     5     6  how can i increase the speed of my internet co...
# 3   3     7     8  why am i mentally very lonely  how can i solve it
# 4   4     9    10  which one dissolve in water quikly sugar  salt...
#
#                                            question2  is_duplicate  q1_len  \
# 0  what is the step by step guide to invest in sh...             0      65
# 1  what would happen if the indian government sto...             0      50
# 2  how can internet speed be increased by hacking...             0      72
# 3  find the remainder when 23  24   math  is divi...             0      49
# 4             which fish would survive in salt water             0      75
#
#    q2_len  q1_num_words  q2_num_words  word_common  word_total
# 0      56            14            12           11          23
# 1      87            12            17            8          26
# 2      58            14            10            4          24
# 3      58            12            16            1          22
# 4      38            15             7            4          21

# %%
new_df['word_share'] = round(new_df['word_common']/new_df['word_total'],2)
new_df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  what is the step by step guide to invest in sh...
# 1   1     3     4  what is the story of kohinoor  koh i noor  dia...
# 2   2     5     6  how can i increase the speed of my internet co...
# 3   3     7     8  why am i mentally very lonely  how can i solve it
# 4   4     9    10  which one dissolve in water quikly sugar  salt...
#
#                                            question2  is_duplicate  q1_len  \
# 0  what is the step by step guide to invest in sh...             0      65
# 1  what would happen if the indian government sto...             0      50
# 2  how can internet speed be increased by hacking...             0      72
# 3  find the remainder when 23  24   math  is divi...             0      49
# 4             which fish would survive in salt water             0      75
#
#    q2_len  q1_num_words  q2_num_words  word_common  word_total  word_share
# 0      56            14            12           11          23        0.48
# 1      87            12            17            8          26        0.31
# 2      58            14            10            4          24        0.17
# 3      58            12            16            1          22        0.05
# 4      38            15             7            4          21        0.19

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from nltk) (2025.7.34)
# Requirement already satisfied: tqdm in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\SANHITH
# [nltk_data]     REDDY\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\SANHITH
# [nltk_data]     REDDY\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Advanced Features
from nltk.corpus import stopwords

def fetch_token_features(row):
    
    q1 = row['question1']
    q2 = row['question2']
    
    SAFE_DIV = 0.0001 

    STOP_WORDS = stopwords.words("english")
    
    token_features = [0.0]*8
    
    # Converting the Sentence into Tokens: 
    q1_tokens = q1.split()
    q2_tokens = q2.split()
    
    if len(q1_tokens) == 0 or len(q2_tokens) == 0:
        return token_features

    # Get the non-stopwords in Questions
    q1_words = set([word for word in q1_tokens if word not in STOP_WORDS])
    q2_words = set([word for word in q2_tokens if word not in STOP_WORDS])
    
    #Get the stopwords in Questions
    q1_stops = set([word for word in q1_tokens if word in STOP_WORDS])
    q2_stops = set([word for word in q2_tokens if word in STOP_WORDS])
    
    # Get the common non-stopwords from Question pair
    common_word_count = len(q1_words.intersection(q2_words))
    
    # Get the common stopwords from Question pair
    common_stop_count = len(q1_stops.intersection(q2_stops))
    
    # Get the common Tokens from Question pair
    common_token_count = len(set(q1_tokens).intersection(set(q2_tokens)))
    
    
    token_features[0] = common_word_count / (min(len(q1_words), len(q2_words)) + SAFE_DIV)
    token_features[1] = common_word_count / (max(len(q1_words), len(q2_words)) + SAFE_DIV)
    token_features[2] = common_stop_count / (min(len(q1_stops), len(q2_stops)) + SAFE_DIV)
    token_features[3] = common_stop_count / (max(len(q1_stops), len(q2_stops)) + SAFE_DIV)
    token_features[4] = common_token_count / (min(len(q1_tokens), len(q2_tokens)) + SAFE_DIV)
    token_features[5] = common_token_count / (max(len(q1_tokens), len(q2_tokens)) + SAFE_DIV)
    
    # Last word of both question is same or not
    token_features[6] = int(q1_tokens[-1] == q2_tokens[-1])
    
    # First word of both question is same or not
    token_features[7] = int(q1_tokens[0] == q2_tokens[0])
    
    return token_features

# %%
token_features = new_df.apply(fetch_token_features, axis=1)

new_df["cwc_min"]       = list(map(lambda x: x[0], token_features))
new_df["cwc_max"]       = list(map(lambda x: x[1], token_features))
new_df["csc_min"]       = list(map(lambda x: x[2], token_features))
new_df["csc_max"]       = list(map(lambda x: x[3], token_features))
new_df["ctc_min"]       = list(map(lambda x: x[4], token_features))
new_df["ctc_max"]       = list(map(lambda x: x[5], token_features))
new_df["last_word_eq"]  = list(map(lambda x: x[6], token_features))
new_df["first_word_eq"] = list(map(lambda x: x[7], token_features))

# %%
new_df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  what is the step by step guide to invest in sh...
# 1   1     3     4  what is the story of kohinoor  koh i noor  dia...
# 2   2     5     6  how can i increase the speed of my internet co...
# 3   3     7     8  why am i mentally very lonely  how can i solve it
# 4   4     9    10  which one dissolve in water quikly sugar  salt...
#
#                                            question2  is_duplicate  q1_len  \
# 0  what is the step by step guide to invest in sh...             0      65
# 1  what would happen if the indian government sto...             0      50
# 2  how can internet speed be increased by hacking...             0      72
# 3  find the remainder when 23  24   math  is divi...             0      49
# 4             which fish would survive in salt water             0      75
#
#    q2_len  q1_num_words  q2_num_words  ...  word_total  word_share   cwc_min  \
# 0      56            14            12  ...          23        0.48  0.999980
# 1      87            12            17  ...          26        0.31  0.799984
# 2      58            14            10  ...          24        0.17  0.399992
# 3      58            12            16  ...          22        0.05  0.000000
# 4      38            15             7  ...          21        0.19  0.399992
#
#     cwc_max   csc_min   csc_max   ctc_min   ctc_max  last_word_eq  \
# 0  0.833319  0.999983  0.999983  0.916659  0.785709           0.0
# 1  0.399996  0.749981  0.599988  0.699993  0.466664           0.0
# 2  0.333328  0.399992  0.249997  0.399996  0.285712           0.0
# 3  0.000000  0.000000  0.000000  0.000000  0.000000           0.0
# 4  0.199998  0.999950  0.666644  0.571420  0.307690           0.0
#
#    first_word_eq
# 0            1.0
# 1            1.0
# 2            1.0
# 3            0.0
# 4            1.0
#
# [5 rows x 21 columns]

# %%
import distance


def fetch_length_features(row):
    
    q1 = row['question1']
    q2 = row['question2']
    
    length_features = [0.0]*3
    
    # Converting the Sentence into Tokens: 
    q1_tokens = q1.split()
    q2_tokens = q2.split()
    
    if len(q1_tokens) == 0 or len(q2_tokens) == 0:
        return length_features
    
    # Absolute length features
    length_features[0] = abs(len(q1_tokens) - len(q2_tokens))
    
    #Average Token Length of both Questions
    length_features[1] = (len(q1_tokens) + len(q2_tokens))/2
    
    strs = list(distance.lcsubstrings(q1, q2))
    length_features[2] = len(strs[0]) / (min(len(q1), len(q2)) + 1)
    
    return length_features

# %%
length_features = new_df.apply(fetch_length_features, axis=1)

new_df['abs_len_diff'] = list(map(lambda x: x[0], length_features))
new_df['mean_len'] = list(map(lambda x: x[1], length_features))
new_df['longest_substr_ratio'] = list(map(lambda x: x[2], length_features))
# Out:
# "length_features = new_df.apply(fetch_length_features, axis=1)\n\nnew_df['abs_len_diff'] = list(map(lambda x: x[0], length_features))\nnew_df['mean_len'] = list(map(lambda x: x[1], length_features))\nnew_df['longest_substr_ratio'] = list(map(lambda x: x[2], length_features))"

# %%
new_df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  what is the step by step guide to invest in sh...
# 1   1     3     4  what is the story of kohinoor  koh i noor  dia...
# 2   2     5     6  how can i increase the speed of my internet co...
# 3   3     7     8  why am i mentally very lonely  how can i solve it
# 4   4     9    10  which one dissolve in water quikly sugar  salt...
#
#                                            question2  is_duplicate  q1_len  \
# 0  what is the step by step guide to invest in sh...             0      65
# 1  what would happen if the indian government sto...             0      50
# 2  how can internet speed be increased by hacking...             0      72
# 3  find the remainder when 23  24   math  is divi...             0      49
# 4             which fish would survive in salt water             0      75
#
#    q2_len  q1_num_words  q2_num_words  ...  word_total  word_share   cwc_min  \
# 0      56            14            12  ...          23        0.48  0.999980
# 1      87            12            17  ...          26        0.31  0.799984
# 2      58            14            10  ...          24        0.17  0.399992
# 3      58            12            16  ...          22        0.05  0.000000
# 4      38            15             7  ...          21        0.19  0.399992
#
#     cwc_max   csc_min   csc_max   ctc_min   ctc_max  last_word_eq  \
# 0  0.833319  0.999983  0.999983  0.916659  0.785709           0.0
# 1  0.399996  0.749981  0.599988  0.699993  0.466664           0.0
# 2  0.333328  0.399992  0.249997  0.399996  0.285712           0.0
# 3  0.000000  0.000000  0.000000  0.000000  0.000000           0.0
# 4  0.199998  0.999950  0.666644  0.571420  0.307690           0.0
#
#    first_word_eq
# 0            1.0
# 1            1.0
# 2            1.0
# 3            0.0
# 4            1.0
#
# [5 rows x 21 columns]

# %%
# !pip install fuzzywuzzy
# Out:
# Requirement already satisfied: fuzzywuzzy in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (0.18.0)

# %%
# Fuzzy Features
from fuzzywuzzy import fuzz

def fetch_fuzzy_features(row):
    
    q1 = row['question1']
    q2 = row['question2']
    
    fuzzy_features = [0.0]*4
    
    # fuzz_ratio
    fuzzy_features[0] = fuzz.QRatio(q1, q2)

    # fuzz_partial_ratio
    fuzzy_features[1] = fuzz.partial_ratio(q1, q2)

    # token_sort_ratio
    fuzzy_features[2] = fuzz.token_sort_ratio(q1, q2)

    # token_set_ratio
    fuzzy_features[3] = fuzz.token_set_ratio(q1, q2)

    return fuzzy_features

# %%
fuzzy_features = new_df.apply(fetch_fuzzy_features, axis=1)

# Creating new feature columns for fuzzy features
new_df['fuzz_ratio'] = list(map(lambda x: x[0], fuzzy_features))
new_df['fuzz_partial_ratio'] = list(map(lambda x: x[1], fuzzy_features))
new_df['token_sort_ratio'] = list(map(lambda x: x[2], fuzzy_features))
new_df['token_set_ratio'] = list(map(lambda x: x[3], fuzzy_features))

# %%
print(new_df.shape)
new_df.head()
# Out:
# (404290, 25)
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  what is the step by step guide to invest in sh...
# 1   1     3     4  what is the story of kohinoor  koh i noor  dia...
# 2   2     5     6  how can i increase the speed of my internet co...
# 3   3     7     8  why am i mentally very lonely  how can i solve it
# 4   4     9    10  which one dissolve in water quikly sugar  salt...
#
#                                            question2  is_duplicate  q1_len  \
# 0  what is the step by step guide to invest in sh...             0      65
# 1  what would happen if the indian government sto...             0      50
# 2  how can internet speed be increased by hacking...             0      72
# 3  find the remainder when 23  24   math  is divi...             0      49
# 4             which fish would survive in salt water             0      75
#
#    q2_len  q1_num_words  q2_num_words  ...   csc_min   csc_max   ctc_min  \
# 0      56            14            12  ...  0.999983  0.999983  0.916659
# 1      87            12            17  ...  0.749981  0.599988  0.699993
# 2      58            14            10  ...  0.399992  0.249997  0.399996
# 3      58            12            16  ...  0.000000  0.000000  0.000000
# 4      38            15             7  ...  0.999950  0.666644  0.571420
#
#     ctc_max  last_word_eq  first_word_eq  fuzz_ratio  fuzz_partial_ratio  \
# 0  0.785709           0.0            1.0          93                 100
# 1  0.466664           0.0            1.0          66                  74
# 2  0.285712           0.0            1.0          43                  46
# 3  0.000000           0.0            0.0           9                  11
# 4  0.307690           0.0            1.0          35                  55
#
#    token_sort_ratio  token_set_ratio
# 0                93              100
# 1                63               86
# 2                63               63
# 3                25               28
# 4                47               67
#
# [5 rows x 25 columns]

# %%
sns.pairplot(new_df[['ctc_min', 'cwc_min', 'csc_min', 'is_duplicate']],hue='is_duplicate')

# %%
sns.pairplot(new_df[['ctc_max', 'cwc_max', 'csc_max', 'is_duplicate']],hue='is_duplicate')

# %%
sns.pairplot(new_df[['last_word_eq', 'first_word_eq', 'is_duplicate']],hue='is_duplicate')

# %%
#sns.pairplot(new_df[['mean_len', 'abs_len_diff','longest_substr_ratio', 'is_duplicate']],hue='is_duplicate')'''

# %%
sns.pairplot(new_df[['fuzz_ratio', 'fuzz_partial_ratio','token_sort_ratio','token_set_ratio', 'is_duplicate']],hue='is_duplicate')

# %%
from sklearn.preprocessing import MinMaxScaler

X = MinMaxScaler().fit_transform(
    new_df[['cwc_min', 'cwc_max', 'csc_min', 'csc_max',
            'ctc_min', 'ctc_max', 'last_word_eq', 'first_word_eq',
            'token_set_ratio', 'token_sort_ratio',
            'fuzz_ratio', 'fuzz_partial_ratio']]
)
y = new_df['is_duplicate'].values

# %%
from sklearn.manifold import TSNE

tsne2d = TSNE(
    n_components=2,
    init='random',  # or 'pca'
    random_state=101,
    method='barnes_hut',
    max_iter=1000,   
    verbose=2,
    angle=0.5
).fit_transform(X)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 404290 samples in 1.896s...
# [t-SNE] Computed neighbors for 404290 samples in 384.961s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 404290
# [t-SNE] Computed conditional probabilities for sample 2000 / 404290
# [t-SNE] Computed conditional probabilities for sample 3000 / 404290
# [t-SNE] Computed conditional probabilities for sample 4000 / 404290
# [t-SNE] Computed conditional probabilities for sample 5000 / 404290
# [t-SNE] Computed conditional probabilities for sample 6000 / 404290
# [t-SNE] Computed conditional probabilities for sample 7000 / 404290
# [t-SNE] Computed conditional probabilities for sample 8000 / 404290
# [t-SNE] Computed conditional probabilities for sample 9000 / 404290
# [t-SNE] Computed conditional probabilities for sample 10000 / 404290
# [t-SNE] Computed conditional probabilities for sample 11000 / 404290
# [t-SNE] Computed conditional probabilities for sample 12000 / 404290
# [t-SNE] Computed conditional probabilities for sample 13000 / 404290
# [t-SNE] Computed conditional probabilities for sample 14000 / 404290
# [t-SNE] Computed conditional probabilities for sample 15000 / 404290
# [t-SNE] Computed conditional probabilities for sample 16000 / 404290
# [t-SNE] Computed conditional probabilities for sample 17000 / 404290
# [t-SNE] Computed conditional probabilities for sample 18000 / 404290
# [t-SNE] Computed conditional probabilities for sample 19000 / 404290
# [t-SNE] Computed conditional probabilities for sample 20000 / 404290
# [t-SNE] Computed conditional probabilities for sample 21000 / 404290
# [t-SNE] Computed conditional probabilities for sample 22000 / 404290
# [t-SNE] Computed conditional probabilities for sample 23000 / 404290
# [t-SNE] Computed conditional probabilities for sample 24000 / 404290
# [t-SNE] Computed conditional probabilities for sample 25000 / 404290
# [t-SNE] Computed conditional probabilities for sample 26000 / 404290
# [t-SNE] Computed conditional probabilities for sample 27000 / 404290
# [t-SNE] Computed conditional probabilities for sample 28000 / 404290
# [t-SNE] Computed conditional probabilities for sample 29000 / 404290
# [t-SNE] Computed conditional probabilities for sample 30000 / 404290
# [t-SNE] Computed conditional probabilities for sample 31000 / 404290
# [t-SNE] Computed conditional probabilities for sample 32000 / 404290
# [t-SNE] Computed conditional probabilities for sample 33000 / 404290
# [t-SNE] Computed conditional probabilities for sample 34000 / 404290
# [t-SNE] Computed conditional probabilities for sample 35000 / 404290
# [t-SNE] Computed conditional probabilities for sample 36000 / 404290
# [t-SNE] Computed conditional probabilities for sample 37000 / 404290
# [t-SNE] Computed conditional probabilities for sample 38000 / 404290
# [t-SNE] Computed conditional probabilities for sample 39000 / 404290
# [t-SNE] Computed conditional probabilities for sample 40000 / 404290
# [t-SNE] Computed conditional probabilities for sample 41000 / 404290
# [t-SNE] Computed conditional probabilities for sample 42000 / 404290
# [t-SNE] Computed conditional probabilities for sample 43000 / 404290
# [t-SNE] Computed conditional probabilities for sample 44000 / 404290
# [t-SNE] Computed conditional probabilities for sample 45000 / 404290
# [t-SNE] Computed conditional probabilities for sample 46000 / 404290
# [t-SNE] Computed conditional probabilities for sample 47000 / 404290
# [t-SNE] Computed conditional probabilities for sample 48000 / 404290
# [t-SNE] Computed conditional probabilities for sample 49000 / 404290
# [t-SNE] Computed conditional probabilities for sample 50000 / 404290
# [t-SNE] Computed conditional probabilities for sample 51000 / 404290
# [t-SNE] Computed conditional probabilities for sample 52000 / 404290
# [t-SNE] Computed conditional probabilities for sample 53000 / 404290
# [t-SNE] Computed conditional probabilities for sample 54000 / 404290
# [t-SNE] Computed conditional probabilities for sample 55000 / 404290
# [t-SNE] Computed conditional probabilities for sample 56000 / 404290
# [t-SNE] Computed conditional probabilities for sample 57000 / 404290
# [t-SNE] Computed conditional probabilities for sample 58000 / 404290
# [t-SNE] Computed conditional probabilities for sample 59000 / 404290
# [t-SNE] Computed conditional probabilities for sample 60000 / 404290
# [t-SNE] Computed conditional probabilities for sample 61000 / 404290
# [t-SNE] Computed conditional probabilities for sample 62000 / 404290
# [t-SNE] Computed conditional probabilities for sample 63000 / 404290
# [t-SNE] Computed conditional probabilities for sample 64000 / 404290
# [t-SNE] Computed conditional probabilities for sample 65000 / 404290
# [t-SNE] Computed conditional probabilities for sample 66000 / 404290
# [t-SNE] Computed conditional probabilities for sample 67000 / 404290
# [t-SNE] Computed conditional probabilities for sample 68000 / 404290
# [t-SNE] Computed conditional probabilities for sample 69000 / 404290
# [t-SNE] Computed conditional probabilities for sample 70000 / 404290
# [t-SNE] Computed conditional probabilities for sample 71000 / 404290
# [t-SNE] Computed conditional probabilities for sample 72000 / 404290
# [t-SNE] Computed conditional probabilities for sample 73000 / 404290
# [t-SNE] Computed conditional probabilities for sample 74000 / 404290
# [t-SNE] Computed conditional probabilities for sample 75000 / 404290
# [t-SNE] Computed conditional probabilities for sample 76000 / 404290
# [t-SNE] Computed conditional probabilities for sample 77000 / 404290
# [t-SNE] Computed conditional probabilities for sample 78000 / 404290
# [t-SNE] Computed conditional probabilities for sample 79000 / 404290
# [t-SNE] Computed conditional probabilities for sample 80000 / 404290
# [t-SNE] Computed conditional probabilities for sample 81000 / 404290
# [t-SNE] Computed conditional probabilities for sample 82000 / 404290
# [t-SNE] Computed conditional probabilities for sample 83000 / 404290
# [t-SNE] Computed conditional probabilities for sample 84000 / 404290
# [t-SNE] Computed conditional probabilities for sample 85000 / 404290
# [t-SNE] Computed conditional probabilities for sample 86000 / 404290
# [t-SNE] Computed conditional probabilities for sample 87000 / 404290
# [t-SNE] Computed conditional probabilities for sample 88000 / 404290
# [t-SNE] Computed conditional probabilities for sample 89000 / 404290
# [t-SNE] Computed conditional probabilities for sample 90000 / 404290
# [t-SNE] Computed conditional probabilities for sample 91000 / 404290
# [t-SNE] Computed conditional probabilities for sample 92000 / 404290
# [t-SNE] Computed conditional probabilities for sample 93000 / 404290
# [t-SNE] Computed conditional probabilities for sample 94000 / 404290
# [t-SNE] Computed conditional probabilities for sample 95000 / 404290
# [t-SNE] Computed conditional probabilities for sample 96000 / 404290
# [t-SNE] Computed conditional probabilities for sample 97000 / 404290
# [t-SNE] Computed conditional probabilities for sample 98000 / 404290
# [t-SNE] Computed conditional probabilities for sample 99000 / 404290
# [t-SNE] Computed conditional probabilities for sample 100000 / 404290
# [t-SNE] Computed conditional probabilities for sample 101000 / 404290
# [t-SNE] Computed conditional probabilities for sample 102000 / 404290
# [t-SNE] Computed conditional probabilities for sample 103000 / 404290
# [t-SNE] Computed conditional probabilities for sample 104000 / 404290
# [t-SNE] Computed conditional probabilities for sample 105000 / 404290
# [t-SNE] Computed conditional probabilities for sample 106000 / 404290
# [t-SNE] Computed conditional probabilities for sample 107000 / 404290
# [t-SNE] Computed conditional probabilities for sample 108000 / 404290
# [t-SNE] Computed conditional probabilities for sample 109000 / 404290
# [t-SNE] Computed conditional probabilities for sample 110000 / 404290
# [t-SNE] Computed conditional probabilities for sample 111000 / 404290
# [t-SNE] Computed conditional probabilities for sample 112000 / 404290
# [t-SNE] Computed conditional probabilities for sample 113000 / 404290
# [t-SNE] Computed conditional probabilities for sample 114000 / 404290
# [t-SNE] Computed conditional probabilities for sample 115000 / 404290
# [t-SNE] Computed conditional probabilities for sample 116000 / 404290
# [t-SNE] Computed conditional probabilities for sample 117000 / 404290
# [t-SNE] Computed conditional probabilities for sample 118000 / 404290
# [t-SNE] Computed conditional probabilities for sample 119000 / 404290
# [t-SNE] Computed conditional probabilities for sample 120000 / 404290
# [t-SNE] Computed conditional probabilities for sample 121000 / 404290
# [t-SNE] Computed conditional probabilities for sample 122000 / 404290
# [t-SNE] Computed conditional probabilities for sample 123000 / 404290
# [t-SNE] Computed conditional probabilities for sample 124000 / 404290
# [t-SNE] Computed conditional probabilities for sample 125000 / 404290
# [t-SNE] Computed conditional probabilities for sample 126000 / 404290
# [t-SNE] Computed conditional probabilities for sample 127000 / 404290
# [t-SNE] Computed conditional probabilities for sample 128000 / 404290
# [t-SNE] Computed conditional probabilities for sample 129000 / 404290
# [t-SNE] Computed conditional probabilities for sample 130000 / 404290
# [t-SNE] Computed conditional probabilities for sample 131000 / 404290
# [t-SNE] Computed conditional probabilities for sample 132000 / 404290
# [t-SNE] Computed conditional probabilities for sample 133000 / 404290
# [t-SNE] Computed conditional probabilities for sample 134000 / 404290
# [t-SNE] Computed conditional probabilities for sample 135000 / 404290
# [t-SNE] Computed conditional probabilities for sample 136000 / 404290
# [t-SNE] Computed conditional probabilities for sample 137000 / 404290
# [t-SNE] Computed conditional probabilities for sample 138000 / 404290
# [t-SNE] Computed conditional probabilities for sample 139000 / 404290
# [t-SNE] Computed conditional probabilities for sample 140000 / 404290
# [t-SNE] Computed conditional probabilities for sample 141000 / 404290
# [t-SNE] Computed conditional probabilities for sample 142000 / 404290
# [t-SNE] Computed conditional probabilities for sample 143000 / 404290
# [t-SNE] Computed conditional probabilities for sample 144000 / 404290
# [t-SNE] Computed conditional probabilities for sample 145000 / 404290
# [t-SNE] Computed conditional probabilities for sample 146000 / 404290
# [t-SNE] Computed conditional probabilities for sample 147000 / 404290
# [t-SNE] Computed conditional probabilities for sample 148000 / 404290
# [t-SNE] Computed conditional probabilities for sample 149000 / 404290
# [t-SNE] Computed conditional probabilities for sample 150000 / 404290
# [t-SNE] Computed conditional probabilities for sample 151000 / 404290
# [t-SNE] Computed conditional probabilities for sample 152000 / 404290
# [t-SNE] Computed conditional probabilities for sample 153000 / 404290
# [t-SNE] Computed conditional probabilities for sample 154000 / 404290
# [t-SNE] Computed conditional probabilities for sample 155000 / 404290
# [t-SNE] Computed conditional probabilities for sample 156000 / 404290
# [t-SNE] Computed conditional probabilities for sample 157000 / 404290
# [t-SNE] Computed conditional probabilities for sample 158000 / 404290
# [t-SNE] Computed conditional probabilities for sample 159000 / 404290
# [t-SNE] Computed conditional probabilities for sample 160000 / 404290
# [t-SNE] Computed conditional probabilities for sample 161000 / 404290
# [t-SNE] Computed conditional probabilities for sample 162000 / 404290
# [t-SNE] Computed conditional probabilities for sample 163000 / 404290
# [t-SNE] Computed conditional probabilities for sample 164000 / 404290
# [t-SNE] Computed conditional probabilities for sample 165000 / 404290
# [t-SNE] Computed conditional probabilities for sample 166000 / 404290
# [t-SNE] Computed conditional probabilities for sample 167000 / 404290
# [t-SNE] Computed conditional probabilities for sample 168000 / 404290
# [t-SNE] Computed conditional probabilities for sample 169000 / 404290
# [t-SNE] Computed conditional probabilities for sample 170000 / 404290
# [t-SNE] Computed conditional probabilities for sample 171000 / 404290
# [t-SNE] Computed conditional probabilities for sample 172000 / 404290
# [t-SNE] Computed conditional probabilities for sample 173000 / 404290
# [t-SNE] Computed conditional probabilities for sample 174000 / 404290
# [t-SNE] Computed conditional probabilities for sample 175000 / 404290
# [t-SNE] Computed conditional probabilities for sample 176000 / 404290
# [t-SNE] Computed conditional probabilities for sample 177000 / 404290
# [t-SNE] Computed conditional probabilities for sample 178000 / 404290
# [t-SNE] Computed conditional probabilities for sample 179000 / 404290
# [t-SNE] Computed conditional probabilities for sample 180000 / 404290
# [t-SNE] Computed conditional probabilities for sample 181000 / 404290
# [t-SNE] Computed conditional probabilities for sample 182000 / 404290
# [t-SNE] Computed conditional probabilities for sample 183000 / 404290
# [t-SNE] Computed conditional probabilities for sample 184000 / 404290
# [t-SNE] Computed conditional probabilities for sample 185000 / 404290
# [t-SNE] Computed conditional probabilities for sample 186000 / 404290
# [t-SNE] Computed conditional probabilities for sample 187000 / 404290
# [t-SNE] Computed conditional probabilities for sample 188000 / 404290
# [t-SNE] Computed conditional probabilities for sample 189000 / 404290
# [t-SNE] Computed conditional probabilities for sample 190000 / 404290
# [t-SNE] Computed conditional probabilities for sample 191000 / 404290
# [t-SNE] Computed conditional probabilities for sample 192000 / 404290
# [t-SNE] Computed conditional probabilities for sample 193000 / 404290
# [t-SNE] Computed conditional probabilities for sample 194000 / 404290
# [t-SNE] Computed conditional probabilities for sample 195000 / 404290
# [t-SNE] Computed conditional probabilities for sample 196000 / 404290
# [t-SNE] Computed conditional probabilities for sample 197000 / 404290
# [t-SNE] Computed conditional probabilities for sample 198000 / 404290
# [t-SNE] Computed conditional probabilities for sample 199000 / 404290
# [t-SNE] Computed conditional probabilities for sample 200000 / 404290
# [t-SNE] Computed conditional probabilities for sample 201000 / 404290
# [t-SNE] Computed conditional probabilities for sample 202000 / 404290
# [t-SNE] Computed conditional probabilities for sample 203000 / 404290
# [t-SNE] Computed conditional probabilities for sample 204000 / 404290
# [t-SNE] Computed conditional probabilities for sample 205000 / 404290
# [t-SNE] Computed conditional probabilities for sample 206000 / 404290
# [t-SNE] Computed conditional probabilities for sample 207000 / 404290
# [t-SNE] Computed conditional probabilities for sample 208000 / 404290
# [t-SNE] Computed conditional probabilities for sample 209000 / 404290
# [t-SNE] Computed conditional probabilities for sample 210000 / 404290
# [t-SNE] Computed conditional probabilities for sample 211000 / 404290
# [t-SNE] Computed conditional probabilities for sample 212000 / 404290
# [t-SNE] Computed conditional probabilities for sample 213000 / 404290
# [t-SNE] Computed conditional probabilities for sample 214000 / 404290
# [t-SNE] Computed conditional probabilities for sample 215000 / 404290
# [t-SNE] Computed conditional probabilities for sample 216000 / 404290
# [t-SNE] Computed conditional probabilities for sample 217000 / 404290
# [t-SNE] Computed conditional probabilities for sample 218000 / 404290
# [t-SNE] Computed conditional probabilities for sample 219000 / 404290
# [t-SNE] Computed conditional probabilities for sample 220000 / 404290
# [t-SNE] Computed conditional probabilities for sample 221000 / 404290
# [t-SNE] Computed conditional probabilities for sample 222000 / 404290
# [t-SNE] Computed conditional probabilities for sample 223000 / 404290
# [t-SNE] Computed conditional probabilities for sample 224000 / 404290
# [t-SNE] Computed conditional probabilities for sample 225000 / 404290
# [t-SNE] Computed conditional probabilities for sample 226000 / 404290
# [t-SNE] Computed conditional probabilities for sample 227000 / 404290
# [t-SNE] Computed conditional probabilities for sample 228000 / 404290
# [t-SNE] Computed conditional probabilities for sample 229000 / 404290
# [t-SNE] Computed conditional probabilities for sample 230000 / 404290
# [t-SNE] Computed conditional probabilities for sample 231000 / 404290
# [t-SNE] Computed conditional probabilities for sample 232000 / 404290
# [t-SNE] Computed conditional probabilities for sample 233000 / 404290
# [t-SNE] Computed conditional probabilities for sample 234000 / 404290
# [t-SNE] Computed conditional probabilities for sample 235000 / 404290
# [t-SNE] Computed conditional probabilities for sample 236000 / 404290
# [t-SNE] Computed conditional probabilities for sample 237000 / 404290
# [t-SNE] Computed conditional probabilities for sample 238000 / 404290
# [t-SNE] Computed conditional probabilities for sample 239000 / 404290
# [t-SNE] Computed conditional probabilities for sample 240000 / 404290
# [t-SNE] Computed conditional probabilities for sample 241000 / 404290
# [t-SNE] Computed conditional probabilities for sample 242000 / 404290
# [t-SNE] Computed conditional probabilities for sample 243000 / 404290
# [t-SNE] Computed conditional probabilities for sample 244000 / 404290
# [t-SNE] Computed conditional probabilities for sample 245000 / 404290
# [t-SNE] Computed conditional probabilities for sample 246000 / 404290
# [t-SNE] Computed conditional probabilities for sample 247000 / 404290
# [t-SNE] Computed conditional probabilities for sample 248000 / 404290
# [t-SNE] Computed conditional probabilities for sample 249000 / 404290
# [t-SNE] Computed conditional probabilities for sample 250000 / 404290
# [t-SNE] Computed conditional probabilities for sample 251000 / 404290
# [t-SNE] Computed conditional probabilities for sample 252000 / 404290
# [t-SNE] Computed conditional probabilities for sample 253000 / 404290
# [t-SNE] Computed conditional probabilities for sample 254000 / 404290
# [t-SNE] Computed conditional probabilities for sample 255000 / 404290
# [t-SNE] Computed conditional probabilities for sample 256000 / 404290
# [t-SNE] Computed conditional probabilities for sample 257000 / 404290
# [t-SNE] Computed conditional probabilities for sample 258000 / 404290
# [t-SNE] Computed conditional probabilities for sample 259000 / 404290
# [t-SNE] Computed conditional probabilities for sample 260000 / 404290
# [t-SNE] Computed conditional probabilities for sample 261000 / 404290
# [t-SNE] Computed conditional probabilities for sample 262000 / 404290
# [t-SNE] Computed conditional probabilities for sample 263000 / 404290
# [t-SNE] Computed conditional probabilities for sample 264000 / 404290
# [t-SNE] Computed conditional probabilities for sample 265000 / 404290
# [t-SNE] Computed conditional probabilities for sample 266000 / 404290
# [t-SNE] Computed conditional probabilities for sample 267000 / 404290
# [t-SNE] Computed conditional probabilities for sample 268000 / 404290
# [t-SNE] Computed conditional probabilities for sample 269000 / 404290
# [t-SNE] Computed conditional probabilities for sample 270000 / 404290
# [t-SNE] Computed conditional probabilities for sample 271000 / 404290
# [t-SNE] Computed conditional probabilities for sample 272000 / 404290
# [t-SNE] Computed conditional probabilities for sample 273000 / 404290
# [t-SNE] Computed conditional probabilities for sample 274000 / 404290
# [t-SNE] Computed conditional probabilities for sample 275000 / 404290
# [t-SNE] Computed conditional probabilities for sample 276000 / 404290
# [t-SNE] Computed conditional probabilities for sample 277000 / 404290
# [t-SNE] Computed conditional probabilities for sample 278000 / 404290
# [t-SNE] Computed conditional probabilities for sample 279000 / 404290
# [t-SNE] Computed conditional probabilities for sample 280000 / 404290
# [t-SNE] Computed conditional probabilities for sample 281000 / 404290
# [t-SNE] Computed conditional probabilities for sample 282000 / 404290
# [t-SNE] Computed conditional probabilities for sample 283000 / 404290
# [t-SNE] Computed conditional probabilities for sample 284000 / 404290
# [t-SNE] Computed conditional probabilities for sample 285000 / 404290
# [t-SNE] Computed conditional probabilities for sample 286000 / 404290
# [t-SNE] Computed conditional probabilities for sample 287000 / 404290
# [t-SNE] Computed conditional probabilities for sample 288000 / 404290
# [t-SNE] Computed conditional probabilities for sample 289000 / 404290
# [t-SNE] Computed conditional probabilities for sample 290000 / 404290
# [t-SNE] Computed conditional probabilities for sample 291000 / 404290
# [t-SNE] Computed conditional probabilities for sample 292000 / 404290
# [t-SNE] Computed conditional probabilities for sample 293000 / 404290
# [t-SNE] Computed conditional probabilities for sample 294000 / 404290
# [t-SNE] Computed conditional probabilities for sample 295000 / 404290
# [t-SNE] Computed conditional probabilities for sample 296000 / 404290
# [t-SNE] Computed conditional probabilities for sample 297000 / 404290
# [t-SNE] Computed conditional probabilities for sample 298000 / 404290
# [t-SNE] Computed conditional probabilities for sample 299000 / 404290
# [t-SNE] Computed conditional probabilities for sample 300000 / 404290
# [t-SNE] Computed conditional probabilities for sample 301000 / 404290
# [t-SNE] Computed conditional probabilities for sample 302000 / 404290
# [t-SNE] Computed conditional probabilities for sample 303000 / 404290
# [t-SNE] Computed conditional probabilities for sample 304000 / 404290
# [t-SNE] Computed conditional probabilities for sample 305000 / 404290
# [t-SNE] Computed conditional probabilities for sample 306000 / 404290
# [t-SNE] Computed conditional probabilities for sample 307000 / 404290
# [t-SNE] Computed conditional probabilities for sample 308000 / 404290
# [t-SNE] Computed conditional probabilities for sample 309000 / 404290
# [t-SNE] Computed conditional probabilities for sample 310000 / 404290
# [t-SNE] Computed conditional probabilities for sample 311000 / 404290
# [t-SNE] Computed conditional probabilities for sample 312000 / 404290
# [t-SNE] Computed conditional probabilities for sample 313000 / 404290
# [t-SNE] Computed conditional probabilities for sample 314000 / 404290
# [t-SNE] Computed conditional probabilities for sample 315000 / 404290
# [t-SNE] Computed conditional probabilities for sample 316000 / 404290
# [t-SNE] Computed conditional probabilities for sample 317000 / 404290
# [t-SNE] Computed conditional probabilities for sample 318000 / 404290
# [t-SNE] Computed conditional probabilities for sample 319000 / 404290
# [t-SNE] Computed conditional probabilities for sample 320000 / 404290
# [t-SNE] Computed conditional probabilities for sample 321000 / 404290
# [t-SNE] Computed conditional probabilities for sample 322000 / 404290
# [t-SNE] Computed conditional probabilities for sample 323000 / 404290
# [t-SNE] Computed conditional probabilities for sample 324000 / 404290
# [t-SNE] Computed conditional probabilities for sample 325000 / 404290
# [t-SNE] Computed conditional probabilities for sample 326000 / 404290
# [t-SNE] Computed conditional probabilities for sample 327000 / 404290
# [t-SNE] Computed conditional probabilities for sample 328000 / 404290
# [t-SNE] Computed conditional probabilities for sample 329000 / 404290
# [t-SNE] Computed conditional probabilities for sample 330000 / 404290
# [t-SNE] Computed conditional probabilities for sample 331000 / 404290
# [t-SNE] Computed conditional probabilities for sample 332000 / 404290
# [t-SNE] Computed conditional probabilities for sample 333000 / 404290
# [t-SNE] Computed conditional probabilities for sample 334000 / 404290
# [t-SNE] Computed conditional probabilities for sample 335000 / 404290
# [t-SNE] Computed conditional probabilities for sample 336000 / 404290
# [t-SNE] Computed conditional probabilities for sample 337000 / 404290
# [t-SNE] Computed conditional probabilities for sample 338000 / 404290
# [t-SNE] Computed conditional probabilities for sample 339000 / 404290
# [t-SNE] Computed conditional probabilities for sample 340000 / 404290
# [t-SNE] Computed conditional probabilities for sample 341000 / 404290
# [t-SNE] Computed conditional probabilities for sample 342000 / 404290
# [t-SNE] Computed conditional probabilities for sample 343000 / 404290
# [t-SNE] Computed conditional probabilities for sample 344000 / 404290
# [t-SNE] Computed conditional probabilities for sample 345000 / 404290
# [t-SNE] Computed conditional probabilities for sample 346000 / 404290
# [t-SNE] Computed conditional probabilities for sample 347000 / 404290
# [t-SNE] Computed conditional probabilities for sample 348000 / 404290
# [t-SNE] Computed conditional probabilities for sample 349000 / 404290
# [t-SNE] Computed conditional probabilities for sample 350000 / 404290
# [t-SNE] Computed conditional probabilities for sample 351000 / 404290
# [t-SNE] Computed conditional probabilities for sample 352000 / 404290
# [t-SNE] Computed conditional probabilities for sample 353000 / 404290
# [t-SNE] Computed conditional probabilities for sample 354000 / 404290
# [t-SNE] Computed conditional probabilities for sample 355000 / 404290
# [t-SNE] Computed conditional probabilities for sample 356000 / 404290
# [t-SNE] Computed conditional probabilities for sample 357000 / 404290
# [t-SNE] Computed conditional probabilities for sample 358000 / 404290
# [t-SNE] Computed conditional probabilities for sample 359000 / 404290
# [t-SNE] Computed conditional probabilities for sample 360000 / 404290
# [t-SNE] Computed conditional probabilities for sample 361000 / 404290
# [t-SNE] Computed conditional probabilities for sample 362000 / 404290
# [t-SNE] Computed conditional probabilities for sample 363000 / 404290
# [t-SNE] Computed conditional probabilities for sample 364000 / 404290
# [t-SNE] Computed conditional probabilities for sample 365000 / 404290
# [t-SNE] Computed conditional probabilities for sample 366000 / 404290
# [t-SNE] Computed conditional probabilities for sample 367000 / 404290
# [t-SNE] Computed conditional probabilities for sample 368000 / 404290
# [t-SNE] Computed conditional probabilities for sample 369000 / 404290
# [t-SNE] Computed conditional probabilities for sample 370000 / 404290
# [t-SNE] Computed conditional probabilities for sample 371000 / 404290
# [t-SNE] Computed conditional probabilities for sample 372000 / 404290
# [t-SNE] Computed conditional probabilities for sample 373000 / 404290
# [t-SNE] Computed conditional probabilities for sample 374000 / 404290
# [t-SNE] Computed conditional probabilities for sample 375000 / 404290
# [t-SNE] Computed conditional probabilities for sample 376000 / 404290
# [t-SNE] Computed conditional probabilities for sample 377000 / 404290
# [t-SNE] Computed conditional probabilities for sample 378000 / 404290
# [t-SNE] Computed conditional probabilities for sample 379000 / 404290
# [t-SNE] Computed conditional probabilities for sample 380000 / 404290
# [t-SNE] Computed conditional probabilities for sample 381000 / 404290
# [t-SNE] Computed conditional probabilities for sample 382000 / 404290
# [t-SNE] Computed conditional probabilities for sample 383000 / 404290
# [t-SNE] Computed conditional probabilities for sample 384000 / 404290
# [t-SNE] Computed conditional probabilities for sample 385000 / 404290
# [t-SNE] Computed conditional probabilities for sample 386000 / 404290
# [t-SNE] Computed conditional probabilities for sample 387000 / 404290
# [t-SNE] Computed conditional probabilities for sample 388000 / 404290
# [t-SNE] Computed conditional probabilities for sample 389000 / 404290
# [t-SNE] Computed conditional probabilities for sample 390000 / 404290
# [t-SNE] Computed conditional probabilities for sample 391000 / 404290
# [t-SNE] Computed conditional probabilities for sample 392000 / 404290
# [t-SNE] Computed conditional probabilities for sample 393000 / 404290
# [t-SNE] Computed conditional probabilities for sample 394000 / 404290
# [t-SNE] Computed conditional probabilities for sample 395000 / 404290
# [t-SNE] Computed conditional probabilities for sample 396000 / 404290
# [t-SNE] Computed conditional probabilities for sample 397000 / 404290
# [t-SNE] Computed conditional probabilities for sample 398000 / 404290
# [t-SNE] Computed conditional probabilities for sample 399000 / 404290
# [t-SNE] Computed conditional probabilities for sample 400000 / 404290
# [t-SNE] Computed conditional probabilities for sample 401000 / 404290
# [t-SNE] Computed conditional probabilities for sample 402000 / 404290
# [t-SNE] Computed conditional probabilities for sample 403000 / 404290
# [t-SNE] Computed conditional probabilities for sample 404000 / 404290
# [t-SNE] Computed conditional probabilities for sample 404290 / 404290
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] Computed conditional probabilities in 12.480s
# [t-SNE] Iteration 50: error = 139.1487885, gradient norm = 0.0048018 (50 iterations in 199.040s)
# [t-SNE] Iteration 100: error = 116.5648346, gradient norm = 0.0027361 (50 iterations in 144.049s)
# [t-SNE] Iteration 150: error = 110.2190475, gradient norm = 0.0018376 (50 iterations in 143.830s)
# [t-SNE] Iteration 200: error = 106.8006744, gradient norm = 0.0014185 (50 iterations in 140.110s)
# [t-SNE] Iteration 250: error = 104.5896606, gradient norm = 0.0011254 (50 iterations in 139.034s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 104.589661
# [t-SNE] Iteration 300: error = 5.4739618, gradient norm = 0.0021923 (50 iterations in 126.213s)
# [t-SNE] Iteration 350: error = 4.7122641, gradient norm = 0.0023885 (50 iterations in 122.573s)
# [t-SNE] Iteration 400: error = 4.2384553, gradient norm = 0.0023635 (50 iterations in 132.907s)
# [t-SNE] Iteration 450: error = 3.9148798, gradient norm = 0.0022884 (50 iterations in 130.082s)
# [t-SNE] Iteration 500: error = 3.6844943, gradient norm = 0.0020886 (50 iterations in 119.639s)
# [t-SNE] Iteration 550: error = 3.5168149, gradient norm = 0.0018922 (50 iterations in 121.496s)
# [t-SNE] Iteration 600: error = 3.3885629, gradient norm = 0.0017193 (50 iterations in 122.144s)
# [t-SNE] Iteration 650: error = 3.2862453, gradient norm = 0.0015801 (50 iterations in 118.861s)
# [t-SNE] Iteration 700: error = 3.2022233, gradient norm = 0.0014640 (50 iterations in 119.002s)
# [t-SNE] Iteration 750: error = 3.1310320, gradient norm = 0.0013657 (50 iterations in 121.117s)
# [t-SNE] Iteration 800: error = 3.0698769, gradient norm = 0.0012880 (50 iterations in 120.252s)
# [t-SNE] Iteration 850: error = 3.0164557, gradient norm = 0.0012151 (50 iterations in 118.649s)
# [t-SNE] Iteration 900: error = 2.9691415, gradient norm = 0.0011568 (50 iterations in 124.105s)
# [t-SNE] Iteration 950: error = 2.9268179, gradient norm = 0.0011044 (50 iterations in 126.319s)
# [t-SNE] Iteration 1000: error = 2.8888004, gradient norm = 0.0010541 (50 iterations in 131.240s)
# [t-SNE] KL divergence after 1000 iterations: 2.888800

# %%
x_df = pd.DataFrame({'x':tsne2d[:,0], 'y':tsne2d[:,1] ,'label':y})

# draw the plot in appropriate place in the grid
sns.lmplot(data=x_df, x='x', y='y', hue='label', fit_reg=False, size=8,palette="Set1",markers=['s','o'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 x_df = pd.DataFrame({'x':tsne2d[:,0], 'y':tsne2d[:,1] ,'label':y})
#       3 # draw the plot in appropriate place in the grid
#       4 sns.lmplot(data=x_df, x='x', y='y', hue='label', fit_reg=False, size=8,palette="Set1",markers=['s','o'])
#
# NameError: name 'tsne2d' is not defined

# %%
tsne3d = TSNE(
    n_components=3,
    init='random', # pca
    random_state=101,
    method='barnes_hut',
    n_iter=1000,
    verbose=2,
    angle=0.5
).fit_transform(X)

# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Using cached plotly-6.3.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Using cached narwhals-2.1.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in c:\users\sanhith reddy\.conda\envs\quora_env\lib\site-packages (from plotly) (25.0)
# Using cached plotly-6.3.0-py3-none-any.whl (9.8 MB)
# Using cached narwhals-2.1.2-py3-none-any.whl (392 kB)
# Installing collected packages: narwhals, plotly
#
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    ---------------------------------------- 2/2 [plotly]
#
# Successfully installed narwhals-2.1.2 plotly-6.3.0

# %%
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.offline as py
py.init_notebook_mode(connected=True)

trace1 = go.Scatter3d(
    x=tsne3d[:,0],
    y=tsne3d[:,1],
    z=tsne3d[:,2],
    mode='markers',
    marker=dict(
        sizemode='diameter',
        color = y,
        colorscale = 'Portland',
        colorbar = dict(title = 'duplicate'),
        line=dict(color='rgb(255, 255, 255)'),
        opacity=0.75
    )
)

data=[trace1]
layout=dict(height=800, width=800, title='3d embedding with engineered features')
fig=dict(data=data, layout=layout)
py.iplot(fig, filename='3DBubble')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.0.min"</script>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 7
#       3 import plotly.offline as py
#       4 py.init_notebook_mode(connected=True)
#       6 trace1 = go.Scatter3d(
# ----> 7     x=tsne3d[:,0],
#       8     y=tsne3d[:,1],
#       9     z=tsne3d[:,2],
#      10     mode='markers',
#      11     marker=dict(
#      12         sizemode='diameter',
#      13         color = y,
#      14         colorscale = 'Portland',
#      15         colorbar = dict(title = 'duplicate'),
#      16         line=dict(color='rgb(255, 255, 255)'),
#      17         opacity=0.75
#      18     )
#      19 )
#      21 data=[trace1]
#      22 layout=dict(height=800, width=800, title='3d embedding with engineered features')
#
# NameError: name 'tsne3d' is not defined

# %%
ques_df = new_df[['question1','question2']]
ques_df.head()
# Out:
#                                            question1  \
# 0  what is the step by step guide to invest in sh...
# 1  what is the story of kohinoor  koh i noor  dia...
# 2  how can i increase the speed of my internet co...
# 3  why am i mentally very lonely  how can i solve it
# 4  which one dissolve in water quikly sugar  salt...
#
#                                            question2
# 0  what is the step by step guide to invest in sh...
# 1  what would happen if the indian government sto...
# 2  how can internet speed be increased by hacking...
# 3  find the remainder when 23  24   math  is divi...
# 4             which fish would survive in salt water

# %%
final_df = new_df.drop(columns=['id','qid1','qid2','question1','question2'])
print(final_df.shape)
final_df.head()
# Out:
# (404290, 20)
#    is_duplicate  q1_len  q2_len  q1_num_words  q2_num_words  word_common  \
# 0             0      65      56            14            12           11
# 1             0      50      87            12            17            8
# 2             0      72      58            14            10            4
# 3             0      49      58            12            16            1
# 4             0      75      38            15             7            4
#
#    word_total  word_share   cwc_min   cwc_max   csc_min   csc_max   ctc_min  \
# 0          23        0.48  0.999980  0.833319  0.999983  0.999983  0.916659
# 1          26        0.31  0.799984  0.399996  0.749981  0.599988  0.699993
# 2          24        0.17  0.399992  0.333328  0.399992  0.249997  0.399996
# 3          22        0.05  0.000000  0.000000  0.000000  0.000000  0.000000
# 4          21        0.19  0.399992  0.199998  0.999950  0.666644  0.571420
#
#     ctc_max  last_word_eq  first_word_eq  fuzz_ratio  fuzz_partial_ratio  \
# 0  0.785709           0.0            1.0          93                 100
# 1  0.466664           0.0            1.0          66                  74
# 2  0.285712           0.0            1.0          43                  46
# 3  0.000000           0.0            0.0           9                  11
# 4  0.307690           0.0            1.0          35                  55
#
#    token_sort_ratio  token_set_ratio
# 0                93              100
# 1                63               86
# 2                63               63
# 3                25               28
# 4                47               67

# %%
from sklearn.feature_extraction.text import CountVectorizer
# merge texts
questions = list(ques_df['question1']) + list(ques_df['question2'])

cv = CountVectorizer(max_features=3000)
q1_arr, q2_arr = np.vsplit(cv.fit_transform(questions).toarray(),2)

# %%
temp_df1 = pd.DataFrame(q1_arr, index= ques_df.index)
temp_df2 = pd.DataFrame(q2_arr, index= ques_df.index)
temp_df = pd.concat([temp_df1, temp_df2], axis=1)
temp_df.shape
# Out:
# (404290, 6000)

# %%
final_df = pd.concat([final_df, temp_df], axis=1)
print(final_df.shape)
final_df.head()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 final_df = pd.concat([final_df, temp_df], axis=1)
#       2 print(final_df.shape)
#       3 final_df.head()
#
# File ~\.conda\envs\quora_env\Lib\site-packages\pandas\core\reshape\concat.py:395, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380     copy = False
#     382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#    (...)    392     sort=sort,
#     393 )
# --> 395 return op.get_result()
#
# File ~\.conda\envs\quora_env\Lib\site-packages\pandas\core\reshape\concat.py:684, in _Concatenator.get_result(self)
#     680             indexers[ax] = obj_labels.get_indexer(new_labels)
#     682     mgrs_indexers.append((obj._mgr, indexers))
# --> 684 new_data = concatenate_managers(
#     685     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     686 )
#     687 if not self.copy and not using_copy_on_write():
#     688     new_data._consolidate_inplace()
#
# File ~\.conda\envs\quora_env\Lib\site-packages\pandas\core\internals\concat.py:131, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     124 # Assertions disabled for performance
#     125 # for tup in mgrs_indexers:
#     126 #    # caller is responsible for ensuring this
#     127 #    indexers = tup[1]
#     128 #    assert concat_axis not in indexers
#     130 if concat_axis == 0:
# --> 131     mgrs = _maybe_reindex_columns_na_proxy(axes, mgrs_indexers, needs_copy)
#     132     return mgrs[0].concat_horizontal(mgrs, axes)
#     134 if len(mgrs_indexers) > 0 and mgrs_indexers[0][0].nblocks > 0:
#
# File ~\.conda\envs\quora_env\Lib\site-packages\pandas\core\internals\concat.py:230, in _maybe_reindex_columns_na_proxy(axes, mgrs_indexers, needs_copy)
#     220         mgr = mgr.reindex_indexer(
#     221             axes[i],
#     222             indexers[i],
#    (...)    227             use_na_proxy=True,  # only relevant for i==0
#     228         )
#     229     if needs_copy and not indexers:
# --> 230         mgr = mgr.copy()
#     232     new_mgrs.append(mgr)
#     233 return new_mgrs
#
# File ~\.conda\envs\quora_env\Lib\site-packages\pandas\core\internals\managers.py:593, in BaseBlockManager.copy(self, deep)
#     590     else:
#     591         new_axes = list(self.axes)
# --> 593 res = self.apply("copy", deep=deep)
#     594 res.axes = new_axes
#     596 if self.ndim > 1:
#     597     # Avoid needing to re-compute these
#
# File ~\.conda\envs\quora_env\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\.conda\envs\quora_env\Lib\site-packages\pandas\core\internals\blocks.py:822, in Block.copy(self, deep)
#     820 refs: BlockValuesRefs | None
#     821 if deep:
# --> 822     values = values.copy()
#     823     refs = None
#     824 else:
#
# MemoryError: Unable to allocate 9.04 GiB for an array with shape (3000, 404290) and data type int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(final_df.iloc[:,1:].values,final_df.iloc[:,0].values,test_size=0.2,random_state=1)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.763165054787405

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb.fit(X_train,y_train)
y_pred1 = xgb.predict(X_test)
accuracy_score(y_test,y_pred1)
# Out:
# 0.7621756659823394

# %%
from sklearn.metrics import confusion_matrix

# %%
# for random forest model
confusion_matrix(y_test,y_pred)
# Out:
# array([[41194,  9885],
#        [ 9265, 20514]])

# %%
# for xgboost model
confusion_matrix(y_test,y_pred1)
# Out:
# array([[40669, 10410],
#        [ 8820, 20959]])

# %%
def test_common_words(q1,q2):
    w1 = set(map(lambda word: word.lower().strip(), q1.split(" ")))
    w2 = set(map(lambda word: word.lower().strip(), q2.split(" ")))    
    return len(w1 & w2)

# %%
def test_total_words(q1,q2):
    w1 = set(map(lambda word: word.lower().strip(), q1.split(" ")))
    w2 = set(map(lambda word: word.lower().strip(), q2.split(" ")))    
    return (len(w1) + len(w2))

# %%
def test_fetch_token_features(q1,q2):
    
    SAFE_DIV = 0.0001 

    STOP_WORDS = stopwords.words("english")
    
    token_features = [0.0]*8
    
    # Converting the Sentence into Tokens: 
    q1_tokens = q1.split()
    q2_tokens = q2.split()
    
    if len(q1_tokens) == 0 or len(q2_tokens) == 0:
        return token_features

    # Get the non-stopwords in Questions
    q1_words = set([word for word in q1_tokens if word not in STOP_WORDS])
    q2_words = set([word for word in q2_tokens if word not in STOP_WORDS])
    
    #Get the stopwords in Questions
    q1_stops = set([word for word in q1_tokens if word in STOP_WORDS])
    q2_stops = set([word for word in q2_tokens if word in STOP_WORDS])
    
    # Get the common non-stopwords from Question pair
    common_word_count = len(q1_words.intersection(q2_words))
    
    # Get the common stopwords from Question pair
    common_stop_count = len(q1_stops.intersection(q2_stops))
    
    # Get the common Tokens from Question pair
    common_token_count = len(set(q1_tokens).intersection(set(q2_tokens)))
    
    
    token_features[0] = common_word_count / (min(len(q1_words), len(q2_words)) + SAFE_DIV)
    token_features[1] = common_word_count / (max(len(q1_words), len(q2_words)) + SAFE_DIV)
    token_features[2] = common_stop_count / (min(len(q1_stops), len(q2_stops)) + SAFE_DIV)
    token_features[3] = common_stop_count / (max(len(q1_stops), len(q2_stops)) + SAFE_DIV)
    token_features[4] = common_token_count / (min(len(q1_tokens), len(q2_tokens)) + SAFE_DIV)
    token_features[5] = common_token_count / (max(len(q1_tokens), len(q2_tokens)) + SAFE_DIV)
    
    # Last word of both question is same or not
    token_features[6] = int(q1_tokens[-1] == q2_tokens[-1])
    
    # First word of both question is same or not
    token_features[7] = int(q1_tokens[0] == q2_tokens[0])
    
    return token_features

# %%
def test_fetch_length_features(q1,q2):
    
    length_features = [0.0]*3
    
    # Converting the Sentence into Tokens: 
    q1_tokens = q1.split()
    q2_tokens = q2.split()
    
    if len(q1_tokens) == 0 or len(q2_tokens) == 0:
        return length_features
    
    # Absolute length features
    length_features[0] = abs(len(q1_tokens) - len(q2_tokens))
    
    #Average Token Length of both Questions
    length_features[1] = (len(q1_tokens) + len(q2_tokens))/2
    
    strs = list(distance.lcsubstrings(q1, q2))
    length_features[2] = len(strs[0]) / (min(len(q1), len(q2)) + 1)
    
    return length_features

# %%
def test_fetch_fuzzy_features(q1,q2):
    
    fuzzy_features = [0.0]*4
    
    # fuzz_ratio
    fuzzy_features[0] = fuzz.QRatio(q1, q2)

    # fuzz_partial_ratio
    fuzzy_features[1] = fuzz.partial_ratio(q1, q2)

    # token_sort_ratio
    fuzzy_features[2] = fuzz.token_sort_ratio(q1, q2)

    # token_set_ratio
    fuzzy_features[3] = fuzz.token_set_ratio(q1, q2)

    return fuzzy_features

# %%
def query_point_creator(q1,q2):
    
    input_query = []
    
    # preprocess
    q1 = preprocess(q1)
    q2 = preprocess(q2)
    
    # fetch basic features
    input_query.append(len(q1))
    input_query.append(len(q2))
    
    input_query.append(len(q1.split(" ")))
    input_query.append(len(q2.split(" ")))
    
    input_query.append(test_common_words(q1,q2))
    input_query.append(test_total_words(q1,q2))
    input_query.append(round(test_common_words(q1,q2)/test_total_words(q1,q2),2))
    
    # fetch token features
    token_features = test_fetch_token_features(q1,q2)
    input_query.extend(token_features)
    
    # fetch length based features
    length_features = test_fetch_length_features(q1,q2)
    input_query.extend(length_features)
    
    # fetch fuzzy features
    fuzzy_features = test_fetch_fuzzy_features(q1,q2)
    input_query.extend(fuzzy_features)
    
    # bow feature for q1
    q1_bow = cv.transform([q1]).toarray()
    
    # bow feature for q2
    q2_bow = cv.transform([q2]).toarray()
    
    
    
    return np.hstack((np.array(input_query).reshape(1,22),q1_bow,q2_bow))

# %%
q1 = 'Where is the capital of India?'
q2 = 'What is the current capital of Pakistan?'
q3 = 'Which city serves as the capital of India?'
q4 = 'What is the business capital of India?'

# %%
rf.predict(query_point_creator(q1,q4))

# %%
cv

# %%
import pickle

pickle.dump(rf,open('model.pkl','wb'))
pickle.dump(cv,open('cv.pkl','wb'))
